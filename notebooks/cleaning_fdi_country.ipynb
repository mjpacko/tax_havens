# %%
import pandas as pd

# %%
df  = pd.read_csv("../data/clean/fdi_clean.csv")
df.head()
# Out:
#           Country Name Country Code  \
# 0       American Samoa          ASM
# 1  Antigua and Barbuda          ATG
# 2             Anguilla          ANG
# 3                Aruba          ABW
# 4         Bahamas, The          BHS
#
#                                       Indicator Name          2008  \
# 0  Foreign direct investment, net inflows (BoP, c...  0.000000e+00
# 1  Foreign direct investment, net inflows (BoP, c...  1.535734e+08
# 2                                                NaN  0.000000e+00
# 3  Foreign direct investment, net inflows (BoP, c...  1.888268e+07
# 4  Foreign direct investment, net inflows (BoP, c...  8.601562e+08
#
#            2009          2010          2011         2012          2013  \
# 0  0.000000e+00  0.000000e+00  0.000000e+00          0.0  0.000000e+00
# 1  8.398133e+07  9.372257e+07  6.963105e+07  124833151.0  9.288539e+07
# 2  0.000000e+00  0.000000e+00  0.000000e+00          0.0  0.000000e+00
# ...
